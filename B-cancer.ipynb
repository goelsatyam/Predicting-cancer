# %%
import random
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')
data=data.drop(['Unnamed: 32','id'],axis=1)
data['diagnosis']=data['diagnosis'].map({'M':0.0,'B':1.0})

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        0.0        17.99         10.38          122.80     1001.0
# 1        0.0        20.57         17.77          132.90     1326.0
# 2        0.0        19.69         21.25          130.00     1203.0
# 3        0.0        11.42         20.38           77.58      386.1
# 4        0.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.627417    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      1.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000    -0.730029     -0.415185       -0.742636
# radius_mean              -0.730029     1.000000      0.323782        0.997855
# texture_mean             -0.415185     0.323782      1.000000        0.329533
# perimeter_mean           -0.742636     0.997855      0.329533        1.000000
# area_mean                -0.708984     0.987357      0.321086        0.986507
# smoothness_mean          -0.358560     0.170581     -0.023389        0.207278
# compactness_mean         -0.596534     0.506124      0.236702        0.556936
# concavity_mean           -0.696360     0.676764      0.302418        0.716136
# concave points_mean      -0.776614     0.822529      0.293464        0.850977
# symmetry_mean            -0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean    0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
# all columns in data
data.columns
# Out:
# Index([u'diagnosis', u'radius_mean', u'texture_mean', u'perimeter_mean',
#        u'area_mean', u'smoothness_mean', u'compactness_mean',
#        u'concavity_mean', u'concave points_mean', u'symmetry_mean',
#        u'fractal_dimension_mean', u'radius_se', u'texture_se', u'perimeter_se',
#        u'area_se', u'smoothness_se', u'compactness_se', u'concavity_se',
#        u'concave points_se', u'symmetry_se', u'fractal_dimension_se',
#        u'radius_worst', u'texture_worst', u'perimeter_worst', u'area_worst',
#        u'smoothness_worst', u'compactness_worst', u'concavity_worst',
#        u'concave points_worst', u'symmetry_worst', u'fractal_dimension_worst'],
#       dtype='object')

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        0.0        17.99         10.38          122.80     1001.0
# 1        0.0        20.57         17.77          132.90     1326.0
# 2        0.0        19.69         21.25          130.00     1203.0
# 3        0.0        11.42         20.38           77.58      386.1
# 4        0.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
#this function split the data frame in two parts
def split(data,p):
    a=[]
    b=[]
    n=data.shape[0]
    
    for i in range(n):
        x=random.random()
        if x<=p:
            a.append(i)
        else:
            b.append(i)
    return data.iloc[a],data.iloc[b]

# %%
#x is test data and y is train data
x,y=split(data,0.3)

# %%
print x.shape[0],y.shape[0]
# Out:
# 146 423

# %%
#Logistic Regression
def sigmoid(z):
    return 1.0/(1.0+np.exp(-z))

def hypothesis(x,coef):
    h=coef[0]
    for i in xrange(1,len(coef)):
        h+=coef[i]*x[i-1]
  
    return sigmoid(h)
    
def gradient_decent(x,y,coef):
    n1=x.shape[0]
    b=np.array([0.0 for i in xrange(len(coef))],dtype=np.float)
    b1=np.array([[0.0 for i in range(len(coef))] for j in range(len(coef))])
    
    for i in xrange(n1):
        h=hypothesis(x.iloc[i],coef)
       
        b[0]+=(h-float(y.iloc[i]))*(1.0/(float(n1)))
        c1=[[1.0]]
        
        for j in xrange(1,len(coef)):
            b[j]+=(1.0/float(n1))*(h-float(y.iloc[i]))*x.iloc[i,j-1]
            c1.append([x.iloc[i,j-1]])
            
        c1=np.array(c1,dtype=np.float)
        c=c1.reshape((1,len(coef)))
        c1=c1.dot(c)
        c1=c1*h*(1-h)*(1.0/(float(n1)))
        b1+=c1
     
    H=np.linalg.inv(b1)
    H=H.dot(b)
    coef-=H
    return coef        

def LogisticRegression(x,y,iterations):
    coef=np.array([0.0 for i in xrange(x.shape[1]+1)],dtype=np.float)
    
    for iteration in xrange(iterations):
        coef=gradient_decent(x,y,coef)
    return coef

# %%
#training the data
b=LogisticRegression(y.drop('diagnosis',axis=1),y['diagnosis'],20)

# %%
#calculating accuracy on test data
pre=0
p=x.drop(['diagnosis'],axis=1)
for i in range(p.shape[0]): 
    pred = hypothesis(p.iloc[i],b)
    if pred>=0.5:
        o=1.0
    else:
        o=0.0
        
    if o==x.iloc[i]['diagnosis']:
        pre+=1
        
print 'Accuracy :',pre/float(p.shape[0])*100
# Out:
# Accuracy : 95.8904109589

# %%
b
# Out:
# array([ -1.17600400e+02,   1.81293380e+03,  -4.14763431e+01,
#         -5.03490338e+01,  -1.38366217e+01,  -1.39260557e+04,
#          1.56214787e+04,  -8.11208967e+03,  -8.53915212e+03,
#          6.09541319e+03,  -1.92974380e+04,  -8.22754533e+02,
#          4.45352962e+01,   3.51852239e+02,  -3.26424708e+01,
#          2.76511910e+04,  -2.74409361e+04,   2.28768713e+04,
#         -8.99228203e+04,   2.74732383e+04,   2.18232176e+05,
#         -4.90821587e+02,  -1.42291795e+01,  -1.96086088e+01,
#          3.44104971e+00,   1.82739806e+03,   2.31132618e+03,
#         -2.02474455e+03,  -1.87391913e+03,  -6.18074406e+03,
#         -1.58974312e+04])
